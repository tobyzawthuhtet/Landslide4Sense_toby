# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import glob as glob
plt.rcParams.update({'figure.max_open_warning': 0})
# %matplotlib inline

# %%
n = np.random.randint(1,100)


train = h5py.File(r'D:\Landslide\TrainData\img\image_'+str(n)+'.h5', 'r')
print(train.keys())

label = h5py.File(r'D:\Landslide\TrainData\mask\mask_'+str(n)+'.h5','r')
print(label.keys())

data = np.array(train.get('img'))
label_data = np.array(label.get('mask'))

print(data.shape,label_data.shape)

#Training image
for i in range(14):
    plt.figure();
    fig,(ax1,ax2)= plt.subplots(1,2,figsize=(10,10))
    ax1.imshow(data[:,:,i]);
    ax1.set_title('Training data');
    ax2.imshow(label_data);
    ax2.set_title('Label where Landslides occured')
# Out:
# <KeysViewHDF5 ['img']>
# <KeysViewHDF5 ['mask']>
# (128, 128, 14) (128, 128)

# %%
n = np.random.randint(1,100)


train = h5py.File(r'D:\Landslide\TrainData\img\image_'+str(n)+'.h5', 'r')
print(train.keys())

label = h5py.File(r'D:\Landslide\TrainData\mask\mask_'+str(n)+'.h5','r')
print(label.keys())

data = np.array(train.get('img'))
data = data[:,:,12:]
label_data = np.array(label.get('mask'))

print(data.shape,label_data.shape)

plt.imshow(data[:,:,0])
# #Training image
# for i in range(14):
#     plt.figure();
#     fig,(ax1,ax2)= plt.subplots(1,2,figsize=(10,10))
#     ax1.imshow(data[:,:,i]);
#     ax1.set_title('Training data');
#     ax2.imshow(label_data);
#     ax2.set_title('Label where Landslides occured')
# Out:
# <KeysViewHDF5 ['img']>
# <KeysViewHDF5 ['mask']>
# (128, 128, 2) (128, 128)

# %%
data = np.array(train.get('img'))
data1 = data[:,:,1] #Band 2
data2 = data[:,:,2] #Band 3
data3 = data[:,:,3] #Band 4
data4 = data [:,:,7] #Band 8

training_data = np.moveaxis(np.stack((data1,data2,data3,data4)),0,2)

print(f'Stacked data shape {training_data.shape}')
# label_data = np.array(label.get('mask'))
# Out:
# Stacked data shape (128, 128, 4)

# %%
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(2,2,figsize=(10,10))
ax1.imshow(data1)
ax1.set_title('Band 2')
ax2.imshow(data2)
ax2.set_title('Band 3')
ax3.imshow(data3)
ax3.set_title('Band 4')
ax4.imshow(data4)
ax4.set_title('Band 8')
# Out:
# Text(0.5, 1.0, 'Band 8')
